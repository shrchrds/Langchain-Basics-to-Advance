# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_ENDPOINT")
AZURE_REGION = os.getenv("AZURE_REGION")
MODEL_NAME = os.getenv("MODEL_NAME")

# %%
os.environ["AZURE_OPENAI_API_KEY"] = AZURE_OPENAI_API_KEY
os.environ["AZURE_OPENAI_ENDPOINT"]= AZURE_OPENAI_ENDPOINT

# %%
from langchain_openai import AzureOpenAIEmbeddings

# %%
embeddings = AzureOpenAIEmbeddings(model="text-embedding-ada-002")

# %%
sample_text = "I am testing text to embedding"
query_result = embeddings.embed_query(sample_text)

# %%
len(query_result)
# Out:
# 1536

# %%
query_result[:5]
# Out:
# [-0.04333774000406265,
#  -0.0007516933837905526,
#  -0.013608371838927269,
#  0.0007650940679013729,
#  0.014110896736383438]

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('2. DataIngestion/super_DS.txt')
text_docs = loader.load()

# %%
text_docs
# Out:
# [Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 1\nSDS PODCAST\nEPISODE 802:\nIN CASE YOU MISSED\nIT IN JUNE 2024\n    Show Notes: http://www.superdatascience.com/802 2\nJon: 00:02 This is episode number 802, our In Case You Missed it in\nJune episode.\n    00:19 Welcome back to the Super Data Science Podcast. I\'m\nyour host, Jon Krohn. This is an In Case You Missed It\nepisode that highlights the best parts of conversations we\nhad on the show in the last month. This first clip you\'ll\nhear is from my interview with Dr. Jason Yosinski, one of\nmy all-time favorite AI researchers. We had a great\nconversation about making your AI and ML models\nattractive to customers.\n    00:40 In this clip, I got him to speak from his experience as\nCEO of the climate technology startup he founded,\nWindscape AI. This is a great case study if you\'re\nplanning to launch your own AI models commercially.\n00:51 I\'m sure that kind of engineering mindset is applicable to\na lot of our listeners, and it seems like your approach is\nworking. So EDP, a large Portuguese utility company,\nrecently selected Windscape as one of nine startups for its\nrenewable innovation program in Singapore to accelerate\nthe global energy transition. What opportunities do you\nsee emerging from Windscape AI\'s participation in this\nprogram?\n    Jason: 01:16 Yeah. Well, thanks for mentioning that. We did apply for\nthis program. We were selected. EDP is a huge utility. I\nbelieve they\'re the fourth-largest wind owner in the world.\nSo they own tons and tons of turbines. They generate a\nlot of wind energy. When I met with folks from EDP, I\nfound them to be a very forward-looking organization.\nSometimes you get a big company and they\'re impossibly\nslow or something, but these folks are really pushing the\nboundaries, all the boundaries they can, which I thought\nwas super cool.\n    Show Notes: http://www.superdatascience.com/802 3\n01:50 What we hope to get out of it and where that collaboration\nmight go is to pilot our technology, start working with\nthem, see how it works on their wind farms around the\nworld. And then if it does work really well, hopefully we\nroll out more broadly and we can also maybe use that as\na demo for new potential customers.\n    Jon: 02:08 Very cool. So it sounds like EDP is forward-looking. But\nin general, do you counter resistance or hurdles as you\ntry to come to energy utilities and say, "Hey, you could be\nusing AI like Windscape\'s to be improving the efficiency of\nyour systems." Do you encounter resistance or hurdles,\nor is it relatively straightforward to convince people that\nyou\'re doing something valuable?\n    Jason: 02:31 I wouldn\'t say it\'s straightforward. No. Convincing people\nthat what you\'re doing is valuable is maybe always hard. I\nwould say saying the words AI or machine learning\ndoesn\'t immediately open all the doors. It can open some\ndoors. Some of these companies realize that AI might be\nrevolutionizing things that happen internally, and they\'re\nnot quite sure how yet, but maybe we should talk to these\nrandos from Windscape and see what they think.\n02:59 It does open some doors, but not all. Just as probably\nwithin any industry, there are some organizations that\nare very forward-looking and others early adopters of any\ntechnology and others that are slower, that are later\nadopters. They literally, some have told us, "We don\'t care\nwhat you\'re [inaudible 00:03:17], just show us when four\nother companies are using it and then we\'ll consider\nusing it because how we work," which is potentially an\nefficient choice from their perspective.\n    03:27 There\'s also small energy companies and large energy\ncompanies, and there\'s a spectrum there of how you sell\nto these companies and how you get adoption and so on.\nSo yeah, and convincing everyone, it can be hard. You\nShow Notes: http://www.superdatascie ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_spitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)

# %%
docs = text_spitter.split_documents(text_docs)

# %%
docs
# Out:
# [Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 1\nSDS PODCAST\nEPISODE 802:\nIN CASE YOU MISSED'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='IN CASE YOU MISSED\nIT IN JUNE 2024\n    Show Notes: http://www.superdatascience.com/802 2'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 00:02 This is episode number 802, our In Case You Missed it in\nJune episode.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="June episode.\n    00:19 Welcome back to the Super Data Science Podcast. I'm"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='your host, Jon Krohn. This is an In Case You Missed It'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='episode that highlights the best parts of conversations we'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="had on the show in the last month. This first clip you'll"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='hear is from my interview with Dr. Jason Yosinski, one of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='my all-time favorite AI researchers. We had a great\nconversation about making your AI and ML models'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='attractive to customers.\n    00:40 In this clip, I got him to speak from his experience as'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='CEO of the climate technology startup he founded,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Windscape AI. This is a great case study if you're"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='planning to launch your own AI models commercially.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="00:51 I'm sure that kind of engineering mindset is applicable to"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='a lot of our listeners, and it seems like your approach is'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='working. So EDP, a large Portuguese utility company,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='recently selected Windscape as one of nine startups for its'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='renewable innovation program in Singapore to accelerate'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the global energy transition. What opportunities do you'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="see emerging from Windscape AI's participation in this\nprogram?"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='program?\n    Jason: 01:16 Yeah. Well, thanks for mentioning that. We did apply for'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='this program. We were selected. EDP is a huge utility. I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="believe they're the fourth-largest wind owner in the world."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='So they own tons and tons of turbines. They generate a'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='lot of wind energy. When I met with folks from EDP, I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='found them to be a very forward-looking organization.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Sometimes you get a big company and they're impossibly"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='slow or something, but these folks are really pushing the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='boundaries, all the boundaries they can, which I thought\nwas super cool.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='was super cool.\n    Show Notes: http://www.superdatascience.com/802 3'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='01:50 What we hope to get out of it and where that collaboration'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='might go is to pilot our technology, start working with'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='them, see how it works on their wind farms around the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='world. And then if it does work really well, hopefully we'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='roll out more broadly and we can also maybe use that as\na demo for new potential customers.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 02:08 Very cool. So it sounds like EDP is forward-looking. But'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='in general, do you counter resistance or hurdles as you'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='try to come to energy utilities and say, "Hey, you could be'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="using AI like Windscape's to be improving the efficiency of"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='your systems." Do you encounter resistance or hurdles,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="or is it relatively straightforward to convince people that\nyou're doing something valuable?"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Jason: 02:31 I wouldn't say it's straightforward. No. Convincing people"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="that what you're doing is valuable is maybe always hard. I"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='would say saying the words AI or machine learning'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="doesn't immediately open all the doors. It can open some"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='doors. Some of these companies realize that AI might be'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="revolutionizing things that happen internally, and they're"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='not quite sure how yet, but maybe we should talk to these'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='randos from Windscape and see what they think.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='02:59 It does open some doors, but not all. Just as probably'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='within any industry, there are some organizations that'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='are very forward-looking and others early adopters of any'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='technology and others that are slower, that are later'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='adopters. They literally, some have told us, "We don\'t care'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="what you're [inaudible 00:03:17], just show us when four"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="other companies are using it and then we'll consider"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='using it because how we work," which is potentially an\nefficient choice from their perspective.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="03:27 There's also small energy companies and large energy"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="companies, and there's a spectrum there of how you sell"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='to these companies and how you get adoption and so on.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='So yeah, and convincing everyone, it can be hard. You'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 4'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='have to convince people that your technology will work,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="that it won't be a huge headache to adopt. The people in"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="the field need to buy into it. It can't ruin their workflow or"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='something. It has to be possible to actually integrate. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="some of these systems run software that's hard to work"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='with and simply integrating can be difficult at times. So I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="don't know, there's a lot of factors probably as in any\nindustry."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="industry.\n    Jon: 04:10 Yeah, it makes so much sense. And hopefully I'm not"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='going too deep here, and if I am asking a question that'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='would give away some kind of IP, just feel free to not'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='answer this. But it seems to me like in a situation like'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='yours, where you are providing software to hardware'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='companies, say the turbine manufacturers, you are not,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='at least in the immediate term, planning on building, say\nyour own turbines, your own wind farms.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='04:37 You are a software company. You need to be partnering'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='with turbine manufacturers, with wind farm operators.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='How does that work? Are people... I guess maybe your'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="response is going to be similar, where there's a range of"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='responses where some turbine manufacturers are'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='relatively early adopters. They see the potential. They say,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='"Wow, Jason\'s done a lot of amazing research in the past.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='He seems like the kind of person we should be working'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='with to accelerate our roadmap." And then other folks are'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='just like, "Yeah, we\'ve got our own team," or I don\'t know.\nHow does it look for you? Yeah.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jason: 05:09 What we started this whole endeavor, what we imagined'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='would happen is we would first build products that we'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='would sell to people that own the turbines. Why do they'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='want them? Because our product would help them make'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='more money starting next month. We help them make'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='more money. They like our product, we roll out, they tell'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='their friends. We deploy to more and more farms, more'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='and more companies. As we start to increase our market'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 5'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='penetration in the industry, then much later, turbine'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='manufacturers would notice and they would say, "Hey,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="everyone's using these Windscape people. Maybe we"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='should talk to them and consider integrating their thing'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='off the factory floor rather than an as aftermarket add-on\non."'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='on."\n    05:48 That\'s still the process we\'re following, although we\'ve'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='been surprised that some OEMs are interested in chatting'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="early. I think they just want to have on their radar what's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="going on in the world. And if there's any promising"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="technology, they want to be there first. So I guess we're"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='already having some of those conversations too.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 06:05 And now, we move from offers that tech companies can'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='refuse to regulations that startups have a duty to follow.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='In this clip with the systems engineering and AI'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='regulation guru, Dr. Gina Guillaume-Joseph, she lays out'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the evolving regulatory field for AI, which can be difficult'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="to navigate even if you've got the best of intentions."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Specifically, Gina and I talk about the AI Bill of Rights,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the NIST AI regulatory framework, and her work on the\nMITRE ATLAS.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="MITRE ATLAS.\n    06:32 Explain for us... You mentioned there, so there's the NIST"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='AI risk management framework. So NIST is the National'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Institutes of Science and Technology, that may be familiar'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='as an acronym. The NIST thing is something for those of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='us who have done any deep learning to kind of Hello'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='world deep learning example involves this handwritten'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="data set of digits. So it's 60,000 handwritten digits done"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='by, if I remember correctly, US postal workers, as well as'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="elementary school students. And so it's just each image is"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="a different digit. So it's some of them are zero, some are"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='one, some are two, some are threes, all the way up to'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='nine. And this handwritten dataset was curated initially, I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="guess in the '90s, maybe even in the '80s by NIST."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 6'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="07:24 And then Yann Le Cun, who's one of the most famous AI"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='researchers of all time, he modified with his research'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='team at the time, I believe they were AT&T Bell Labs, they'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='modified that NIST handwritten digit dataset to create the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="MNIST, modified NIST, handwritten dataset. So I don't"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="know, it's a bit of an aside, but that MNIST dataset is"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="probably familiar to anyone who's done any kind of deep"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='learning at all. And so yeah, so that same organization,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="NIST, has been around for a long time in the US I don't\nknow how many decades."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='07:58 But has been trying to set up frameworks for all different'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='kinds of industries in science and technology, and has'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='now created this AI risk management framework, which'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="again, I'll have a link to that in the show notes alongside"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the AI Bill of Rights. A third framework, I guess, you can'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="correct me if I'm not using the right word there, that you"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='brought up in your talk that also seems really helpful\nhere is something called the MITRE ATLAS.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="08:26 So I've been trying to, as you've been speaking, dig up"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="what MITRE stands for, M-I-T-R-E. It doesn't seem like it"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='stands for anything. Can you tell us a bit about MITRE'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='and the MITRE ATLAS and then maybe you can weave'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='together these three different things; the AI Bill of Rights,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the NIST AI regulatory framework, as well as MITRE'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='ATLAS. And tell us how we can integrate these three'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='frameworks together in order to have a good sense of how'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='to move forward with the AI systems that we built.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Gina: 08:58 So MITRE is a not-for-profit organization. I worked for'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='them for 10 years, and they support the federal'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='government across all the federal government agencies to'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='help them solve some of the most pressing challenges. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='MITRE operates federally funded research and'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='development centers in support of the federal government'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='to solve problems for a safer world, essentially is what'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='MITRE does. And while at MITRE, I supported multiple'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 7\nagencies; Department of Homeland Security, Social'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Security Administration, Veterans Affairs, Department of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Defense, in some of the challenges that they were facing\nat the time.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='at the time.\n    09:45 Societal challenges to include when the economy was'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='doing some downward slides and banks were failing, part'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='of some of the work that I did was at the FDIC, that was'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='with Booz Allen. But MITRE was involved in other aspects'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='of that as well, to really understand the failures and to'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='figure out the mitigation strategies to ensure that society'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="didn't feel those impacts as broadly and as strongly."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='10:24 And MITRE created the ATLAS threat model introduction,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="threat model. It's this comprehensive coverage of AIspecific adversary tactics techniques that"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='techniques that includes realworld observation and reporting. It talks about'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='accessibility and usability of AI alignment with existing'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='cybersecurity frameworks in terms of from an AI\nperspective. And that community engagement'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='contribution and the educational resources and training.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="10:58 So they're developing a detailed taxonomy of tactics, of"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='techniques, of procedures specific to AI systems that'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='cover the entire lifecycle from data collection to model'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='development and deployment and maintenance. Where\nthey establish those mechanisms for continuously'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='gathering and updating threat intelligence based on realworld cybersecurity incidents involving AI'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='involving AI so that the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="knowledge base remains current and relevant. So that's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='what MITRE is doing it with their MITRE ATLAS'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='framework. And the framework integrates their existing'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='MITRE attack for enterprise framework that shows that'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='they bring in that consistency and interoperability across'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="cybersecurity efforts as it pertains to AI systems. And\nthat's MITRE ATLAS threat model."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 8'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 12:01 Terrifically useful context there from Gina. In my next'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='clip, Alex Andorra and I discuss Bayesian statistics,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='namely why being able to crunch larger and larger data'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='sets has helped us to use a powerful modeling technique\nthat was originally devised centuries ago.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='12:15 In addition to the podcast, also, I mentioned this at the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="outset, I said that you're co-founder and principal data"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='scientist of the popular Bayesian stats modeling platform,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="PyMC. So like many things in data science, it's uppercase"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="P, lowercase Y, for Python. What's the MC? PyMC, one\nword, M and the C are capitalized."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Alex: 12:38 So it's very confusing because it stands for Python and"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='then MC is Monte Carlo. So I understand, but why Monte'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Carlo? It's because it comes from Markov chain Monte"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Carlo. So actually, it should be PyMCMC or PyMC'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="squared, which is what I'm saying since the beginning."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="But anyways, yeah, it's actually PyMC squared. So for"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Markov chain Monte Carlo and Markov chain Monte Carlo'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='is one of the main ways... All the algorithms now, new'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='ones, but the blockbuster algorithm to run Bayesian\nmodels is to use MCMC.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 13:21 So in the same way that stochastic gradient descent is'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='like the defacto standard for finding your model weights'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='in machine learning, Markov chain Monte Carlo is the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='standard way of doing it with the Bayesian network?'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Alex: 13:36 Yeah. Yeah, yeah. And so now there are newer versions,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="more efficient versions. That's basically the name of the"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='game, making the algorithm more and more efficient. But'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the first algorithm dates back... I think it was actually'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='invented during the project Manhattan. So during World\nWar II.\nJon: 13:57 Theme of the day.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 9'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Alex: 13:58 Yeah. And lots of physicists actually, statistical physics is'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="a field that's contributed a lot to MCMC. And so yeah,"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='physicists who came to the field of statistics and trying to'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='make the algorithms more efficient for their models. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='they have contributed a lot. The field of physics has'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='contributed a lot of big names and people to great leaps'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="into the realm of more efficient algorithms. And so, I don't"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='know who your audience is, but that may sound boring.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="14:37 Yeah, the algorithm, it's like the workhorse, but it's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="extremely powerful. And that's also one of the main"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='reasons why Bayesian statistics are increasing in'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="popularity lately, because I'm going to argue that it's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='always been the best framework to do statistics, to do'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='science. But it was hard to do with pen and paper'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='because the problem is that you have a huge, nasty'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='integral on the numerator, on the denominator, sorry.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='And this integral is not computable by pen and paper. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='for a long, long time, Bayesian statistics combined two'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='features like campaigns, PR campaigns. Bayesian'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='statistics was relegated to the margins because it was just\nsuper hard to do.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='super hard to do.\n15:31 And so for other problems, other than very trivial ones, it'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='was not very applicable. But now with the advent of\npersonal computing, you have these incredible'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="algorithms. So now most of the time, it's HMC, Hamilton"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="and Monte Carlo. That's what we use under the hood with"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='PyMC. But if you stand, if you use [inaudible 00:15:54] ,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="it's the same. And thanks to these algorithms, now we"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='can make extremely powerful models because we can'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='approximate the [inaudible 00:16:03] distributions thanks'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="to, well, computer's computing power. A computer is very"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="good at computing. I think that's why it's called that."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Jon: 16:15 Yes. And so that reminds me of deep learning. It's a"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='similar kind of thing where the applications we have'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='today, like your ChatGPT or whatever your favorite large'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 10'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='language model is, these amazing. Video generation like'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Sora, all of this is happening thanks to deep learning,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="which is an approach we've had since the '50s. Certainly"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='not as old as Bayesian statistics, but similarly, it has'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='been able to take off with much larger data sets and\nmuch more compute.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='much more compute.\nAlex: 16:46 Yeah, yeah. Yeah, yeah, very good point. And I think'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="that's even more the point in deep learning for sure,"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="because Bayesian stats doesn't need the scale, but the"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="way we're doing deep learning for now, definitely need the\nscale."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='scale.\nJon: 16:58 Yeah, yeah. Scale of data.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Alex: 17:00 Yeah, yeah, exactly. Yeah, sorry, yeah, the scale, because'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="our two scales, data and computing. Yeah. You're right."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 17:05 And for model parameters. So that has actually... I mean,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='tying back to something you said near the beginning of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='this episode, is that actually one of the advantages of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Bayesian statistics is that you can do it with very few'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='data. Maybe fewer data than with a frequentist approach'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='or a machine learning approach, because you can bake in'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='your prior assumptions. And those prior assumptions'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='give some kind of structure, some kind of framework for\nyour data to make an impact.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Alex: 17:32 Yeah. Yeah, completely.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 17:34 And in keeping with the theme of returning to the past to'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='find golden opportunities, I speak to Dr. Nathan Lambert'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='about historical influences on contemporary\nmethodologies. I also managed to sneak in a question'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='about reinforcement learning from human feedback.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Nathan is a research scientist for the Allen Institute for'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='AI, and previously built out the RLHF team at Hugging'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Face. So there was no better person to ask about the lack'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 11'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='of robustness in RLHF and how that could impact the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='future development and deployment of AI systems.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="18:02 Another really cool thing that you've done related to RLHF"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='is you have traced it back to ancient philosophy and'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='modern economics. So mentioning Aristotle and von'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Neumann-Morganstern utility theorem, for example. I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="don't really know what the VNM utility theorem is, but"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='how do these historical foundations influence current'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='methodologies and what can modern AI research learn\nfrom these early theories?'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Nathan: 18:30 Yeah. So this is a fun paper with a few colleagues that I'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="started working with at Berkeley, and now we're kind of"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='spread out. This is all based on the fact that RL is very'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='deep field multidisciplinary history, where it goes way'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='back. And then the notion of preference is a very vague'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="thing in economics. And it's like the von NeumannMorganstern theory is a foundational thing that"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="essentially it's like you can express either all behaviors or"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='all goals as probability and expected value distributions,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='which essentially lets you do expected value math over\npreferences.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='preferences.\n19:10 And then it led to a bunch of debates on whether or not'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='preferences actually exist and are tractable in any of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="these things, or if they're actually measurable or not due"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='to the preference shift over time based on context. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="these are the kinds of things that we take and it's ask a"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='lot of questions on how this impacts the modern RLHF'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="process. It's things like is the final model's preferences,"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="which is like we're mapping onto very human terms, is"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='that actually based more on the the base model, which is'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='scraped from the internet than the human preferences\nthat they get from somewhere like Scale AI.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="19:46 So it's like if it's based more on the internet crawling than"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="this million dollar dataset they're getting from Scale AI,"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 12'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="it's kind of confusing to the marketing where we're saying"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="we're learning a preference model, but it might not"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='actually do that much. Is other things like OpenAI now'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="has a ton of user data and it's like what does the"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='economics literature say about generating data for'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='training that comes from a user context or a professional'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="context where someone is paid to do it and they're paid to"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="act in a certain way? And how does all of this mix? So it's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='really just a super long list of questions of why we should'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="look at other social sciences if we're making grand claims"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='about human preferences and all of these things.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Jon: 20:26 Nice. Well, fascinating. Tons to dig into there for our'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="listeners. Final topic that I planned related to RLHF, I'm"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="sure it'll come up again organically in the conversation,"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="but you've mentioned that RLHF is not even robust to"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='fine-tuning. And so removing the safety layer from models'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='like GPT-4 and Llama 2 can break down the notion of'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='safety. Can you elaborate on the implications of this'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='fragility for the future development and deployment of AI\nsystems?'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="systems?\nNathan: 20:59 Yeah, so this is a specific line of research. So there's a few"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='papers that showed that if you take a model like Zephyr'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='or Tulu that we were mentioning, if they have safety in'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the dataset, if you then go and fine-tune it again on some'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="different tasks, you'll do some of the behaviors that are"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='"ingrained" in the model. I honestly think this is a little'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="bit more clickbaity than actually worrisome because it's"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='really not surprising given that if you just look at the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='amount of compute applied at fine-tuning, we pre-trained'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='these models for trillions of tokens. And then we apply a'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='couple billion tokens of compute at fine-tuning.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="21:36 And it's like we're not changing the weights of the model"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="substantially. We're doing a slight nudge, and it makes"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='sense that a slight nudge could be undone at the same'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='way. But if you were to take this to some of the bigger'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 13'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='labs, what you hear is that safety is not just a single'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='artifact thing. Safety is much more about a complete'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='system than a model. So open weight models being'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="unsafe or unsafe, I don't consider to be that big of a deal."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="It's like if you were to apply them to a free endpoint that"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="everyone on the internet could talk to, then I don't want"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='my model saying good things about Hitler and all these\nobvious things.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="obvious things.\n22:09 But if it's a research artifact that you need to spin up"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="GPUs to use yourself, and it's a little bit more... I'm more"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='open to having these diversity of models exist. But if you'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='ask [inaudible 00:22:22] or somebody, it\'s like, "What'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='happens... How do you get safety into your model?" And'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="it's like, it's not just RLHF. You need to have safety at the"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='pre-training, any preference model you trained. And then'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='all of these models have a safety filter on the output. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='ChatGPT, it reads all the text generated from the base'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="model, and then there's a go, no go where it will rephrase"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='the text if it gets a no-go signal, which is like their content\nmoderation API.'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="moderation API.\n22:45 So it's kind of a double. It's the type of thing where"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="researchers need to market their work, but it's not as big"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="of a detail as I think it is. It's like, okay, I think it has"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='interesting business downstream things with liability. So'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="it's just like if you want to fine-tune a Llama model, you"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='normally do that on your own hardware, but OpenAI has'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='a fine-tuning API. And if they claim their model is safe,'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='but any fine-tuning on their API that they then host'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='makes it unsafe, that seems like more of a business'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="problem. Which is like, oh, it's a nice way that open"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='ecosystem might be better off because it breaks the'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="liability chain. But we'll see this research continue to"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="evolve. It's so early in all of these things for a year in."),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="Jon: 23:31 All right. That's it for today's In Case You Missed It"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='episode, to be sure not to miss any of our exciting'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='Show Notes: http://www.superdatascience.com/802 14'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='upcoming episodes. Be sure to subscribe to this podcast'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="if you haven't already. But most importantly, I hope you'll"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='just keep on listening. Until next time, keep on rocking it'),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content="out there. And I'm looking forward to enjoying another"),
#  Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='round of Super Data Science Podcast with you very soon.')]

# %%
from langchain_community.vectorstores import Chroma

# %%
db = Chroma.from_documents(docs, embeddings)

# %%
db

# %%
query = "Who is CEO of the climate technology startup?"
retrieved_results = db.similarity_search(query)

# %%
print(retrieved_results)
# Out:
# [Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='CEO of the climate technology startup he founded,'), Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='CEO of the climate technology startup he founded,'), Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='might go is to pilot our technology, start working with'), Document(metadata={'source': '2. DataIngestion/super_DS.txt'}, page_content='recently selected Windscape as one of nine startups for its')]

# %% [markdown]
# ## Ollama Embeddings

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
ollama_embeddings = OllamaEmbeddings(model="gemma2")

# %%
ollama_embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma2', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = ollama_embeddings.embed_documents(
    ["Machine Learning is subset of AI",
    "Deep Learning is subset of Machine Learning",
    "Generative AI is subset of Deep Learning"]
)

# %%
len(r1[0])
# Out:
# 3584

# %%
r1[0][:5]
# Out:
# [1.3644047975540161,
#  -2.029574155807495,
#  0.8655009865760803,
#  0.20633915066719055,
#  0.13833169639110565]

# %%
ollama_embeddings.embed_query("What is Fine Tuning in LLM?")
# Out:
# [0.2738792598247528,
#  -4.164581775665283,
#  1.229740023612976,
#  0.4063176214694977,
#  -1.4627341032028198,
#  0.8538913726806641,
#  0.4768451154232025,
#  -2.386324405670166,
#  0.06878752261400223,
#  -0.33146798610687256,
#  0.03195326030254364,
#  -1.199082374572754,
#  1.1926424503326416,
#  0.7652331590652466,
#  -1.8698513507843018,
#  -1.75541090965271,
#  -0.5379906892776489,
#  -1.050007939338684,
#  0.5904436111450195,
#  -1.7746533155441284,
#  -0.9248797297477722,
#  -0.6103386282920837,
#  0.5016844868659973,
#  -0.9110485911369324,
#  0.06548342853784561,
#  1.708531141281128,
#  0.1459168791770935,
#  0.9467202425003052,
#  0.0845254585146904,
#  -0.450916051864624,
#  1.191080093383789,
#  1.8175444602966309,
#  -0.05149640887975693,
#  -1.585858702659607,
#  -1.2190237045288086,
#  1.4729827642440796,
#  -2.2854294776916504,
#  -1.302834153175354,
#  -0.18700580298900604,
#  -0.07087133824825287,
#  -1.6684198379516602,
#  -0.08466356247663498,
#  -0.14323948323726654,
#  -2.0685760974884033,
#  -0.3775668442249298,
#  0.6254717707633972,
#  -0.1360173225402832,
#  -1.4974595308303833,
#  0.39511555433273315,
#  1.8870593309402466,
#  -0.18139715492725372,
#  -0.3121742606163025,
#  0.3524512052536011,
#  0.6251846551895142,
#  1.873131275177002,
#  1.2100123167037964,
#  -1.5710296630859375,
#  0.539713978767395,
#  -1.8296023607254028,
#  -0.6342768669128418,
#  -1.8807826042175293,
#  -0.537659227848053,
#  -0.12030760943889618,
#  0.19320175051689148,
#  -0.58487868309021,
#  -1.074591875076294,
#  1.5253045558929443,
#  2.212623357772827,
#  0.27031296491622925,
#  1.4437845945358276,
#  2.488163471221924,
#  -0.6087899804115295,
#  -0.5248827934265137,
#  1.760221004486084,
#  -0.721901535987854,
#  -0.8755539655685425,
#  1.7068895101547241,
#  1.2805485725402832,
#  -0.5429983139038086,
#  1.3907365798950195,
#  2.5587589740753174,
#  1.1575162410736084,
#  0.630389392375946,
#  1.4640846252441406,
#  -3.3963077068328857,
#  -0.40643996000289917,
#  2.789642333984375,
#  -0.3517087996006012,
#  -0.9060076475143433,
#  -0.4171959459781647,
#  -1.3406251668930054,
#  1.0591721534729004,
#  2.0927398204803467,
#  1.330603003501892,
#  -0.5572200417518616,
#  1.96464204788208,
#  1.9940104484558105,
#  -0.4883410334587097,
#  1.8271268606185913,
#  -1.4076675176620483,
#  0.500368058681488,
#  0.5176119208335876,
#  0.2250494658946991,
#  1.4223198890686035,
#  0.4718385636806488,
#  1.0262452363967896,
#  -0.1530933827161789,
#  0.08252109587192535,
#  -0.22754891216754913,
#  1.3280396461486816,
#  ...]

# %% [markdown]
# ## Huggingface Embeddings

# %%
load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"] = os.getenv("HUGGINGFACE_API_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
hf_embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
text = "I am trying to use huggingface embeedings"
query_result = hf_embeddings.embed_query(text)
print(len(query_result))
# Out:
# 384

# %%
query_result[:5]
# Out:
# [-0.05429377779364586,
#  0.019458668306469917,
#  0.021442962810397148,
#  0.006438622251152992,
#  -0.01802055723965168]
